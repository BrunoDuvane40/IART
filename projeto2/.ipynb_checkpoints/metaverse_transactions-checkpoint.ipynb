# %% [markdown]
# # Supervised Learning Project - Metaverse Transactions
#
# The Open Metaverse is a vast and interconnected virtual world that operates without a central authority. In this digital landscape, blockchain technology is essential for handling transactions, overseeing digital possessions, and maintaining secure and transparent interactions among users. This dataset is designed to capture the intricate and ever-changing blockchain activities within the metaverse, serving as a fundamental resource for exploring and advancing metaverse-related technologies.
#
# Our goal is to detect the existence of anomalies within a transaction by evaluating based on the supevised learning model we are building

# %%
# %reset -f

import pandas as pd 
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier, ExtraTreesClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.dummy import DummyClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from lightgbm import LGBMClassifier
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay


metaverse_data = pd.read_csv('metaverse_transactions_dataset.csv')

metaverse_data.head()
# Out:
#              timestamp  hour_of_day  \
# 0  2022-04-11 12:47:27           12
# 1  2022-06-14 19:12:46           19
# 2  2022-01-18 16:26:59           16
# 3  2022-06-15 09:20:04            9
# 4  2022-02-18 14:35:30           14
#
#                               sending_address  \
# 0  0x9d32d0bf2c00f41ce7ca01b66e174cc4dcb0c1da
# 1  0xd6e251c23cbf52dbd472f079147873e655d8096f
# 2  0x2e0925b922fed01f6a85d213ae2718f54b8ca305
# 3  0x93efefc25fcaf31d7695f28018d7a11ece55457f
# 4  0xad3b8de45d63f5cce28aef9a82cf30c397c6ceb9
#
#                             receiving_address      amount transaction_type  \
# 0  0x39f82e1c09bc6d7baccc1e79e5621ff812f50572  796.949206         transfer
# 1  0x51e8fbe24f124e0e30a614e14401b9bbfed5384c    0.010000         purchase
# 2  0x52c7911879f783d590af45bda0c0ef2b8536706f  778.197390         purchase
# 3  0x8ac3b7bd531b3a833032f07d4e47c7af6ea7bace  300.838358         transfer
# 4  0x6fdc047c2391615b3facd79b4588c7e9106e49f2  775.569344             sale
#
#   location_region  ip_prefix  login_frequency  session_duration  \
# 0          Europe    192.000                3                48
# 1   South America    172.000                5                61
# 2            Asia    192.168                3                74
# 3   South America    172.000                8               111
# 4          Africa    172.160                6               100
#
#   purchase_pattern    age_group  risk_score        anomaly
# 0          focused  established       18.75       low_risk
# 1          focused  established       25.00       low_risk
# 2          focused  established       31.25       low_risk
# 3       high_value      veteran       36.75       low_risk
# 4       high_value      veteran       62.50  moderate_risk

# %%
metaverse_data.describe()
# Out:
#         hour_of_day        amount     ip_prefix  login_frequency  \
# count  78600.000000  78600.000000  78600.000000     78600.000000
# mean      11.532634    502.574903    147.644430         4.178702
# std        6.935897    245.898146     69.388143         2.366038
# min        0.000000      0.010000     10.000000         1.000000
# 25%        6.000000    331.319966    172.000000         2.000000
# 50%       12.000000    500.029500    172.160000         4.000000
# 75%       18.000000    669.528311    192.000000         6.000000
# max       23.000000   1557.150905    192.168000         8.000000
#
#        session_duration    risk_score
# count      78600.000000  78600.000000
# mean          69.684606     44.956722
# std           40.524476     21.775365
# min           20.000000     15.000000
# 25%           35.000000     26.250000
# 50%           60.000000     40.000000
# 75%          100.000000     52.500000
# max          159.000000    100.000000

# %% [markdown]
# Now we will take a look at the number of rows and columns avaiulable in the dataset:

# %%
print("Number of rows:", metaverse_data.shape[0])
print("Number of columns:", metaverse_data.shape[1])
# Out:
# Number of rows: 78600
# Number of columns: 14

# %% [markdown]
# Now, lets look at data types:

# %%
metaverse_data.describe()
# Out:
#         hour_of_day        amount     ip_prefix  login_frequency  \
# count  78600.000000  78600.000000  78600.000000     78600.000000
# mean      11.532634    502.574903    147.644430         4.178702
# std        6.935897    245.898146     69.388143         2.366038
# min        0.000000      0.010000     10.000000         1.000000
# 25%        6.000000    331.319966    172.000000         2.000000
# 50%       12.000000    500.029500    172.160000         4.000000
# 75%       18.000000    669.528311    192.000000         6.000000
# max       23.000000   1557.150905    192.168000         8.000000
#
#        session_duration    risk_score
# count      78600.000000  78600.000000
# mean          69.684606     44.956722
# std           40.524476     21.775365
# min           20.000000     15.000000
# 25%           35.000000     26.250000
# 50%           60.000000     40.000000
# 75%          100.000000     52.500000
# max          159.000000    100.000000

# %%
print(metaverse_data.dtypes)
# Out:
# timestamp             object
# hour_of_day            int64
# sending_address       object
# receiving_address     object
# amount               float64
# transaction_type      object
# location_region       object
# ip_prefix            float64
# login_frequency        int64
# session_duration       int64
# purchase_pattern      object
# age_group             object
# risk_score           float64
# anomaly               object
# dtype: object

# %% [markdown]
# As you can see, we have two columns regarding time, timestamp and hour of day, to simplify our job we will drop the timestamp column as they both pratically refer to the same thing

# %%
metaverse_data.drop(columns=['timestamp'], inplace=True)

# %% [markdown]
# Lets look at the first rows to see the effects of dropping the column

# %%
metaverse_data.head()
# Out:
#    hour_of_day                             sending_address  \
# 0           12  0x9d32d0bf2c00f41ce7ca01b66e174cc4dcb0c1da
# 1           19  0xd6e251c23cbf52dbd472f079147873e655d8096f
# 2           16  0x2e0925b922fed01f6a85d213ae2718f54b8ca305
# 3            9  0x93efefc25fcaf31d7695f28018d7a11ece55457f
# 4           14  0xad3b8de45d63f5cce28aef9a82cf30c397c6ceb9
#
#                             receiving_address      amount transaction_type  \
# 0  0x39f82e1c09bc6d7baccc1e79e5621ff812f50572  796.949206         transfer
# 1  0x51e8fbe24f124e0e30a614e14401b9bbfed5384c    0.010000         purchase
# 2  0x52c7911879f783d590af45bda0c0ef2b8536706f  778.197390         purchase
# 3  0x8ac3b7bd531b3a833032f07d4e47c7af6ea7bace  300.838358         transfer
# 4  0x6fdc047c2391615b3facd79b4588c7e9106e49f2  775.569344             sale
#
#   location_region  ip_prefix  login_frequency  session_duration  \
# 0          Europe    192.000                3                48
# 1   South America    172.000                5                61
# 2            Asia    192.168                3                74
# 3   South America    172.000                8               111
# 4          Africa    172.160                6               100
#
#   purchase_pattern    age_group  risk_score        anomaly
# 0          focused  established       18.75       low_risk
# 1          focused  established       25.00       low_risk
# 2          focused  established       31.25       low_risk
# 3       high_value      veteran       36.75       low_risk
# 4       high_value      veteran       62.50  moderate_risk

# %%
metaverse_data.isnull().sum()
# Out:
# hour_of_day          0
# sending_address      0
# receiving_address    0
# amount               0
# transaction_type     0
# location_region      0
# ip_prefix            0
# login_frequency      0
# session_duration     0
# purchase_pattern     0
# age_group            0
# risk_score           0
# anomaly              0
# dtype: int64

# %% [markdown]
# We can see that there are no missing values, but we can still check for duplicate data:

# %%
metaverse_data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There is also no duplicated data

# %% [markdown]
# We have chosen to remove the receiving and sending addresses, as we aren't sure about how to handle them, as they are not numerical, and enconding them wouldn't pose us that great of an advantage.
#
# Of course we could argue that knowing addresses involved with high anomaly risk would be a great indicator as it is probably the same person involved. But, we don't think that in a real world scenario, with a test set these variables could be of great value.

# %%
metaverse_data.drop(columns=['receiving_address'],  inplace=True)
metaverse_data.drop(columns=['sending_address'], inplace=True)

metaverse_data.head()
# Out:
#    hour_of_day      amount transaction_type location_region  ip_prefix  \
# 0           12  796.949206         transfer          Europe    192.000
# 1           19    0.010000         purchase   South America    172.000
# 2           16  778.197390         purchase            Asia    192.168
# 3            9  300.838358         transfer   South America    172.000
# 4           14  775.569344             sale          Africa    172.160
#
#    login_frequency  session_duration purchase_pattern    age_group  \
# 0                3                48          focused  established
# 1                5                61          focused  established
# 2                3                74          focused  established
# 3                8               111       high_value      veteran
# 4                6               100       high_value      veteran
#
#    risk_score        anomaly
# 0       18.75       low_risk
# 1       25.00       low_risk
# 2       31.25       low_risk
# 3       36.75       low_risk
# 4       62.50  moderate_risk

# %% [markdown]
# We'll now encode the remaining categorical variables so we can use them all in our models

# %%
metaverse_data['transaction_type'] = LabelEncoder().fit_transform(metaverse_data['transaction_type'])
metaverse_data['location_region'] = LabelEncoder().fit_transform(metaverse_data['location_region'])
metaverse_data['purchase_pattern'] = LabelEncoder().fit_transform(metaverse_data['purchase_pattern'])
metaverse_data['age_group'] = LabelEncoder().fit_transform(metaverse_data['age_group'])

metaverse_data.head()
# Out:
#    hour_of_day      amount  transaction_type  location_region  ip_prefix  \
# 0           12  796.949206                 4                2    192.000
# 1           19    0.010000                 1                4    172.000
# 2           16  778.197390                 1                1    192.168
# 3            9  300.838358                 4                4    172.000
# 4           14  775.569344                 2                0    172.160
#
#    login_frequency  session_duration  purchase_pattern  age_group  risk_score  \
# 0                3                48                 0          0       18.75
# 1                5                61                 0          0       25.00
# 2                3                74                 0          0       31.25
# 3                8               111                 1          2       36.75
# 4                6               100                 1          2       62.50
#
#          anomaly
# 0       low_risk
# 1       low_risk
# 2       low_risk
# 3       low_risk
# 4  moderate_risk

# %% [markdown]
# Now since risk score and anomaly are correlated lets see exactly how they correlate, by seeing what the value boundaries are for a certain risk score to be high, medium, or low for example. To do that lets plot a risk score to anomaly graphic.

# %%
sns.boxplot(x='risk_score', y='anomaly', data=metaverse_data)
plt.title('Anomaly vs Risk Score')

plt.show()

# %% [markdown]
# We can now clearly see the ranges of each risk,
#
# By observing the plot we can see that by risk score, from 0-60 corresponds to low_risk, from 60-90, to moderate_risk, and from 90 onwards to high risk
#
# Now lets take a look at the distribution of these classes on the whole dataset, this will allow us to later know whether we want to sample our training data or not, in case it is too imbalanced. Ideally we want a balanced data set, so it handles the test set better

# %%
grouped_data = metaverse_data.groupby('anomaly')

for name, group in grouped_data:
    if name == 'low_risk':
        low_risk = group.copy()
    elif name == 'high_risk':
        high_risk = group.copy()
    elif name == 'moderate_risk':
        moderate_risk = group.copy()

print("Low Risk Transactions:", len(low_risk))
print("High Risk Transactions:", len(high_risk))
print("Moderate Risk Transactions:", len(moderate_risk))
# Out:
# Low Risk Transactions: 63494
# High Risk Transactions: 6495
# Moderate Risk Transactions: 8611

# %% [markdown]
# As you can see from the output, we will need to apply sampling so we have a more balanced training set which will prepare our model for the test set.
#
# To have a more efficient test we analyzed column by column, to see if perhaps one of the columns would probably not be of help, and by doing that we got to the region column. We calculated the average risk score by region, to see if maybe one region had more scams than the others. Let's take a look:

# %%
risk_average = metaverse_data.groupby('location_region')['risk_score'].mean()

plt.figure(figsize=(10, 6))

plt.bar(risk_average.index, risk_average.values, color='skyblue')


plt.title('Average Risk Score by Location Region')
plt.xlabel('Location Region')
plt.ylabel('Average Risk Score')

plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# It seems like all regions have similar averages. Our interpretation is that the region won't influence our model in the evaluation, so we may drop that column.

# %%
metaverse_data.drop(columns=['location_region'], inplace=True)

metaverse_data.head()
# Out:
#    hour_of_day      amount  transaction_type  ip_prefix  login_frequency  \
# 0           12  796.949206                 4    192.000                3
# 1           19    0.010000                 1    172.000                5
# 2           16  778.197390                 1    192.168                3
# 3            9  300.838358                 4    172.000                8
# 4           14  775.569344                 2    172.160                6
#
#    session_duration  purchase_pattern  age_group  risk_score        anomaly
# 0                48                 0          0       18.75       low_risk
# 1                61                 0          0       25.00       low_risk
# 2                74                 0          0       31.25       low_risk
# 3               111                 1          2       36.75       low_risk
# 4               100                 1          2       62.50  moderate_risk

# %% [markdown]
# We are now left with 10 of the original 14 columns, allowing us to now proceed to the preparation of our training set. We will start by also encoding our target variable, which will allow us to construct/build our model.

# %%
metaverse_data['anomaly'] = LabelEncoder().fit_transform(metaverse_data['anomaly'])

metaverse_data.head()
# Out:
#    hour_of_day      amount  transaction_type  ip_prefix  login_frequency  \
# 0           12  796.949206                 4    192.000                3
# 1           19    0.010000                 1    172.000                5
# 2           16  778.197390                 1    192.168                3
# 3            9  300.838358                 4    172.000                8
# 4           14  775.569344                 2    172.160                6
#
#    session_duration  purchase_pattern  age_group  risk_score  anomaly
# 0                48                 0          0       18.75        1
# 1                61                 0          0       25.00        1
# 2                74                 0          0       31.25        1
# 3               111                 1          2       36.75        1
# 4               100                 1          2       62.50        2

# %% [markdown]
# Lets take a look at our data types again

# %%
metaverse_data.dtypes
# Out:
# hour_of_day           int64
# amount              float64
# transaction_type      int64
# ip_prefix           float64
# login_frequency       int64
# session_duration      int64
# purchase_pattern      int64
# age_group             int64
# risk_score          float64
# anomaly               int64
# dtype: object

# %% [markdown]
# Lets now split our data into inputs and the output/target:

# %%
input_data = metaverse_data.drop(columns=['anomaly'], axis=1)
output_data = metaverse_data['anomaly']

# %% [markdown]
# As we previously saw, there is a huge imbalance in our data set between high_risk and moderate and low risk:
#
# Low Risk Transactions: 63494
# High Risk Transactions: 6495
# Moderate Risk Transactions: 8611
#
# Due to the imbalance we will use sampling to address our issue, but first lets split the data into training and test set:

# %%
X_train, X_test, y_train, y_test = train_test_split(input_data, output_data, test_size=0.2, random_state=42)

X_train, y_train = SMOTE(random_state=42).fit_resample(X_train, y_train)

y_train.value_counts(), y_test.value_counts()
# Out:
# (anomaly
#  1    50646
#  2    50646
#  0    50646
#  Name: count, dtype: int64,
#  anomaly
#  1    12848
#  2     1621
#  0     1251
#  Name: count, dtype: int64)

# %% [markdown]
# Now that we have everything prepared, we can start the training

# %%
from pycaret.classification import *

classification = setup(data = metaverse_data, train_size=0.8, target = 'anomaly', session_id=42, normalize=True, transformation=True)

best = compare_models()

results = pull()
results
# Out:
# <style type="text/css">
# #T_877ab_row8_col1, #T_877ab_row12_col1, #T_877ab_row14_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_877ab">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_877ab_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_877ab_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_877ab_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_877ab_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_877ab_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_877ab_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_877ab_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_877ab_row1_col1" class="data row1 col1" >anomaly</td>
#     </tr>
#     <tr>
#       <th id="T_877ab_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_877ab_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_877ab_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_877ab_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_877ab_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_877ab_row3_col1" class="data row3 col1" >(78600, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_877ab_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_877ab_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_877ab_row4_col1" class="data row4 col1" >(78600, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_877ab_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_877ab_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_877ab_row5_col1" class="data row5 col1" >(62880, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_877ab_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_877ab_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_877ab_row6_col1" class="data row6 col1" >(15720, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_877ab_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_877ab_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_877ab_row7_col1" class="data row7 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_877ab_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_877ab_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_877ab_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_877ab_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_877ab_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_877ab_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_877ab_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_877ab_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_877ab_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_877ab_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_877ab_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_877ab_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_877ab_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_877ab_row12_col0" class="data row12 col0" >Transformation</td>
#       <td id="T_877ab_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_877ab_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_877ab_row13_col0" class="data row13 col0" >Transformation method</td>
#       <td id="T_877ab_row13_col1" class="data row13 col1" >yeo-johnson</td>
#     </tr>
#     <tr>
#       <th id="T_877ab_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_877ab_row14_col0" class="data row14 col0" >Normalize</td>
#       <td id="T_877ab_row14_col1" class="data row14 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_877ab_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_877ab_row15_col0" class="data row15 col0" >Normalize method</td>
#       <td id="T_877ab_row15_col1" class="data row15 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_877ab_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_877ab_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_877ab_row16_col1" class="data row16 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_877ab_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_877ab_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_877ab_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_877ab_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_877ab_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_877ab_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_877ab_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_877ab_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_877ab_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_877ab_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_877ab_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_877ab_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_877ab_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_877ab_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_877ab_row21_col1" class="data row21 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_877ab_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_877ab_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_877ab_row22_col1" class="data row22 col1" >717e</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_fcb6d th {
#   text-align: left;
# }
# #T_fcb6d_row0_col0, #T_fcb6d_row0_col2, #T_fcb6d_row1_col0, #T_fcb6d_row1_col6, #T_fcb6d_row1_col7, #T_fcb6d_row2_col0, #T_fcb6d_row3_col0, #T_fcb6d_row4_col0, #T_fcb6d_row4_col2, #T_fcb6d_row5_col0, #T_fcb6d_row5_col2, #T_fcb6d_row6_col0, #T_fcb6d_row7_col0, #T_fcb6d_row8_col0, #T_fcb6d_row8_col1, #T_fcb6d_row8_col2, #T_fcb6d_row8_col3, #T_fcb6d_row8_col4, #T_fcb6d_row8_col5, #T_fcb6d_row8_col6, #T_fcb6d_row8_col7, #T_fcb6d_row9_col0, #T_fcb6d_row9_col1, #T_fcb6d_row9_col2, #T_fcb6d_row9_col3, #T_fcb6d_row9_col4, #T_fcb6d_row9_col5, #T_fcb6d_row9_col6, #T_fcb6d_row9_col7, #T_fcb6d_row10_col0, #T_fcb6d_row10_col1, #T_fcb6d_row10_col2, #T_fcb6d_row10_col3, #T_fcb6d_row10_col4, #T_fcb6d_row10_col5, #T_fcb6d_row10_col6, #T_fcb6d_row10_col7, #T_fcb6d_row11_col0, #T_fcb6d_row11_col1, #T_fcb6d_row11_col2, #T_fcb6d_row11_col3, #T_fcb6d_row11_col4, #T_fcb6d_row11_col5, #T_fcb6d_row11_col6, #T_fcb6d_row11_col7, #T_fcb6d_row12_col0, #T_fcb6d_row12_col1, #T_fcb6d_row12_col2, #T_fcb6d_row12_col3, #T_fcb6d_row12_col4, #T_fcb6d_row12_col5, #T_fcb6d_row12_col6, #T_fcb6d_row12_col7, #T_fcb6d_row13_col0, #T_fcb6d_row13_col1, #T_fcb6d_row13_col2, #T_fcb6d_row13_col3, #T_fcb6d_row13_col4, #T_fcb6d_row13_col5, #T_fcb6d_row13_col6, #T_fcb6d_row13_col7 {
#   text-align: left;
# }
# #T_fcb6d_row0_col1, #T_fcb6d_row0_col3, #T_fcb6d_row0_col4, #T_fcb6d_row0_col5, #T_fcb6d_row0_col6, #T_fcb6d_row0_col7, #T_fcb6d_row1_col1, #T_fcb6d_row1_col2, #T_fcb6d_row1_col3, #T_fcb6d_row1_col4, #T_fcb6d_row1_col5, #T_fcb6d_row2_col1, #T_fcb6d_row2_col2, #T_fcb6d_row2_col3, #T_fcb6d_row2_col4, #T_fcb6d_row2_col5, #T_fcb6d_row2_col6, #T_fcb6d_row2_col7, #T_fcb6d_row3_col1, #T_fcb6d_row3_col2, #T_fcb6d_row3_col3, #T_fcb6d_row3_col4, #T_fcb6d_row3_col5, #T_fcb6d_row3_col6, #T_fcb6d_row3_col7, #T_fcb6d_row4_col1, #T_fcb6d_row4_col3, #T_fcb6d_row4_col4, #T_fcb6d_row4_col5, #T_fcb6d_row4_col6, #T_fcb6d_row4_col7, #T_fcb6d_row5_col1, #T_fcb6d_row5_col3, #T_fcb6d_row5_col4, #T_fcb6d_row5_col5, #T_fcb6d_row5_col6, #T_fcb6d_row5_col7, #T_fcb6d_row6_col1, #T_fcb6d_row6_col2, #T_fcb6d_row6_col3, #T_fcb6d_row6_col4, #T_fcb6d_row6_col5, #T_fcb6d_row6_col6, #T_fcb6d_row6_col7, #T_fcb6d_row7_col1, #T_fcb6d_row7_col2, #T_fcb6d_row7_col3, #T_fcb6d_row7_col4, #T_fcb6d_row7_col5, #T_fcb6d_row7_col6, #T_fcb6d_row7_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_fcb6d_row0_col8, #T_fcb6d_row1_col8, #T_fcb6d_row2_col8, #T_fcb6d_row3_col8, #T_fcb6d_row4_col8, #T_fcb6d_row5_col8, #T_fcb6d_row6_col8, #T_fcb6d_row7_col8, #T_fcb6d_row8_col8, #T_fcb6d_row9_col8, #T_fcb6d_row10_col8, #T_fcb6d_row11_col8, #T_fcb6d_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_fcb6d_row13_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_fcb6d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fcb6d_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_fcb6d_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_fcb6d_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_fcb6d_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_fcb6d_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_fcb6d_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_fcb6d_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_fcb6d_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_fcb6d_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fcb6d_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_fcb6d_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_fcb6d_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_fcb6d_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_fcb6d_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_fcb6d_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_fcb6d_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_fcb6d_row0_col6" class="data row0 col6" >1.0000</td>
#       <td id="T_fcb6d_row0_col7" class="data row0 col7" >1.0000</td>
#       <td id="T_fcb6d_row0_col8" class="data row0 col8" >0.4520</td>
#     </tr>
#     <tr>
#       <th id="T_fcb6d_level0_row1" class="row_heading level0 row1" >knn</th>
#       <td id="T_fcb6d_row1_col0" class="data row1 col0" >K Neighbors Classifier</td>
#       <td id="T_fcb6d_row1_col1" class="data row1 col1" >1.0000</td>
#       <td id="T_fcb6d_row1_col2" class="data row1 col2" >1.0000</td>
#       <td id="T_fcb6d_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_fcb6d_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_fcb6d_row1_col5" class="data row1 col5" >1.0000</td>
#       <td id="T_fcb6d_row1_col6" class="data row1 col6" >0.9999</td>
#       <td id="T_fcb6d_row1_col7" class="data row1 col7" >0.9999</td>
#       <td id="T_fcb6d_row1_col8" class="data row1 col8" >0.1580</td>
#     </tr>
#     <tr>
#       <th id="T_fcb6d_level0_row2" class="row_heading level0 row2" >dt</th>
#       <td id="T_fcb6d_row2_col0" class="data row2 col0" >Decision Tree Classifier</td>
#       <td id="T_fcb6d_row2_col1" class="data row2 col1" >1.0000</td>
#       <td id="T_fcb6d_row2_col2" class="data row2 col2" >1.0000</td>
#       <td id="T_fcb6d_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_fcb6d_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_fcb6d_row2_col5" class="data row2 col5" >1.0000</td>
#       <td id="T_fcb6d_row2_col6" class="data row2 col6" >1.0000</td>
#       <td id="T_fcb6d_row2_col7" class="data row2 col7" >1.0000</td>
#       <td id="T_fcb6d_row2_col8" class="data row2 col8" >0.0870</td>
#     </tr>
#     <tr>
#       <th id="T_fcb6d_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_fcb6d_row3_col0" class="data row3 col0" >Random Forest Classifier</td>
#       <td id="T_fcb6d_row3_col1" class="data row3 col1" >1.0000</td>
#       <td id="T_fcb6d_row3_col2" class="data row3 col2" >1.0000</td>
#       <td id="T_fcb6d_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_fcb6d_row3_col4" class="data row3 col4" >1.0000</td>
#       <td id="T_fcb6d_row3_col5" class="data row3 col5" >1.0000</td>
#       <td id="T_fcb6d_row3_col6" class="data row3 col6" >1.0000</td>
#       <td id="T_fcb6d_row3_col7" class="data row3 col7" >1.0000</td>
#       <td id="T_fcb6d_row3_col8" class="data row3 col8" >0.3410</td>
#     </tr>
#     <tr>
#       <th id="T_fcb6d_level0_row4" class="row_heading level0 row4" >ada</th>
#       <td id="T_fcb6d_row4_col0" class="data row4 col0" >Ada Boost Classifier</td>
#       <td id="T_fcb6d_row4_col1" class="data row4 col1" >1.0000</td>
#       <td id="T_fcb6d_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_fcb6d_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_fcb6d_row4_col4" class="data row4 col4" >1.0000</td>
#       <td id="T_fcb6d_row4_col5" class="data row4 col5" >1.0000</td>
#       <td id="T_fcb6d_row4_col6" class="data row4 col6" >1.0000</td>
#       <td id="T_fcb6d_row4_col7" class="data row4 col7" >1.0000</td>
#       <td id="T_fcb6d_row4_col8" class="data row4 col8" >0.3810</td>
#     </tr>
#     <tr>
#       <th id="T_fcb6d_level0_row5" class="row_heading level0 row5" >gbc</th>
#       <td id="T_fcb6d_row5_col0" class="data row5 col0" >Gradient Boosting Classifier</td>
#       <td id="T_fcb6d_row5_col1" class="data row5 col1" >1.0000</td>
#       <td id="T_fcb6d_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_fcb6d_row5_col3" class="data row5 col3" >1.0000</td>
#       <td id="T_fcb6d_row5_col4" class="data row5 col4" >1.0000</td>
#       <td id="T_fcb6d_row5_col5" class="data row5 col5" >1.0000</td>
#       <td id="T_fcb6d_row5_col6" class="data row5 col6" >1.0000</td>
#       <td id="T_fcb6d_row5_col7" class="data row5 col7" >1.0000</td>
#       <td id="T_fc
# Processing:   0%|          | 0/61 [00:00<?, ?it/s]
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# lr                    Logistic Regression    1.0000  0.0000  1.0000  1.0000
# knn                K Neighbors Classifier    1.0000  1.0000  1.0000  1.0000
# dt               Decision Tree Classifier    1.0000  1.0000  1.0000  1.0000
# rf               Random Forest Classifier    1.0000  1.0000  1.0000  1.0000
# ada                  Ada Boost Classifier    1.0000  0.0000  1.0000  1.0000
# gbc          Gradient Boosting Classifier    1.0000  0.0000  1.0000  1.0000
# et                 Extra Trees Classifier    1.0000  1.0000  1.0000  1.0000
# lightgbm  Light Gradient Boosting Machine    1.0000  1.0000  1.0000  1.0000
# svm                   SVM - Linear Kernel    0.9949  0.0000  0.9949  0.9949
# lda          Linear Discriminant Analysis    0.9893  0.0000  0.9893  0.9902
# ridge                    Ridge Classifier    0.9039  0.0000  0.9039  0.9136
# qda       Quadratic Discriminant Analysis    0.8757  0.0000  0.8757  0.8858
# nb                            Naive Bayes    0.8633  0.9957  0.8633  0.9329
# dummy                    Dummy Classifier    0.8078  0.5000  0.8078  0.6526
#
#               F1   Kappa     MCC  TT (Sec)
# lr        1.0000  1.0000  1.0000     0.452
# knn       1.0000  0.9999  0.9999     0.158
# dt        1.0000  1.0000  1.0000     0.087
# rf        1.0000  1.0000  1.0000     0.341
# ada       1.0000  1.0000  1.0000     0.381
# gbc       1.0000  1.0000  1.0000     2.084
# et        1.0000  1.0000  1.0000     0.270
# lightgbm  1.0000  1.0000  1.0000     0.451
# svm       0.9948  0.9843  0.9844     0.097
# lda       0.9895  0.9679  0.9682     0.085
# ridge     0.8697  0.6327  0.6878     0.080
# qda       0.8730  0.6270  0.6459     0.082
# nb        0.8825  0.6721  0.7106     0.087
# dummy     0.7219  0.0000  0.0000     0.077

# %% [markdown]
# The fact that we have 8 algorithms, running with a perfect accuracy is suspicious, some attribute must be outweighting the others, lets check:

# %%
# Create a Decision Tree model
dt = create_model('dt')

# Plot feature importance
plot_model(dt, plot = 'feature')
# Out:
# <style type="text/css">
# #T_01690_row10_col0, #T_01690_row10_col1, #T_01690_row10_col2, #T_01690_row10_col3, #T_01690_row10_col4, #T_01690_row10_col5, #T_01690_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_01690">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_01690_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_01690_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_01690_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_01690_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_01690_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_01690_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_01690_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_01690_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_01690_row0_col0" class="data row0 col0" >1.0000</td>
#       <td id="T_01690_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_01690_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_01690_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_01690_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_01690_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_01690_row0_col6" class="data row0 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_01690_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_01690_row1_col0" class="data row1 col0" >1.0000</td>
#       <td id="T_01690_row1_col1" class="data row1 col1" >1.0000</td>
#       <td id="T_01690_row1_col2" class="data row1 col2" >1.0000</td>
#       <td id="T_01690_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_01690_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_01690_row1_col5" class="data row1 col5" >1.0000</td>
#       <td id="T_01690_row1_col6" class="data row1 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_01690_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_01690_row2_col0" class="data row2 col0" >1.0000</td>
#       <td id="T_01690_row2_col1" class="data row2 col1" >1.0000</td>
#       <td id="T_01690_row2_col2" class="data row2 col2" >1.0000</td>
#       <td id="T_01690_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_01690_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_01690_row2_col5" class="data row2 col5" >1.0000</td>
#       <td id="T_01690_row2_col6" class="data row2 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_01690_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_01690_row3_col0" class="data row3 col0" >1.0000</td>
#       <td id="T_01690_row3_col1" class="data row3 col1" >1.0000</td>
#       <td id="T_01690_row3_col2" class="data row3 col2" >1.0000</td>
#       <td id="T_01690_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_01690_row3_col4" class="data row3 col4" >1.0000</td>
#       <td id="T_01690_row3_col5" class="data row3 col5" >1.0000</td>
#       <td id="T_01690_row3_col6" class="data row3 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_01690_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_01690_row4_col0" class="data row4 col0" >1.0000</td>
#       <td id="T_01690_row4_col1" class="data row4 col1" >1.0000</td>
#       <td id="T_01690_row4_col2" class="data row4 col2" >1.0000</td>
#       <td id="T_01690_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_01690_row4_col4" class="data row4 col4" >1.0000</td>
#       <td id="T_01690_row4_col5" class="data row4 col5" >1.0000</td>
#       <td id="T_01690_row4_col6" class="data row4 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_01690_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_01690_row5_col0" class="data row5 col0" >1.0000</td>
#       <td id="T_01690_row5_col1" class="data row5 col1" >1.0000</td>
#       <td id="T_01690_row5_col2" class="data row5 col2" >1.0000</td>
#       <td id="T_01690_row5_col3" class="data row5 col3" >1.0000</td>
#       <td id="T_01690_row5_col4" class="data row5 col4" >1.0000</td>
#       <td id="T_01690_row5_col5" class="data row5 col5" >1.0000</td>
#       <td id="T_01690_row5_col6" class="data row5 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_01690_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_01690_row6_col0" class="data row6 col0" >1.0000</td>
#       <td id="T_01690_row6_col1" class="data row6 col1" >1.0000</td>
#       <td id="T_01690_row6_col2" class="data row6 col2" >1.0000</td>
#       <td id="T_01690_row6_col3" class="data row6 col3" >1.0000</td>
#       <td id="T_01690_row6_col4" class="data row6 col4" >1.0000</td>
#       <td id="T_01690_row6_col5" class="data row6 col5" >1.0000</td>
#       <td id="T_01690_row6_col6" class="data row6 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_01690_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_01690_row7_col0" class="data row7 col0" >1.0000</td>
#       <td id="T_01690_row7_col1" class="data row7 col1" >1.0000</td>
#       <td id="T_01690_row7_col2" class="data row7 col2" >1.0000</td>
#       <td id="T_01690_row7_col3" class="data row7 col3" >1.0000</td>
#       <td id="T_01690_row7_col4" class="data row7 col4" >1.0000</td>
#       <td id="T_01690_row7_col5" class="data row7 col5" >1.0000</td>
#       <td id="T_01690_row7_col6" class="data row7 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_01690_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_01690_row8_col0" class="data row8 col0" >1.0000</td>
#       <td id="T_01690_row8_col1" class="data row8 col1" >1.0000</td>
#       <td id="T_01690_row8_col2" class="data row8 col2" >1.0000</td>
#       <td id="T_01690_row8_col3" class="data row8 col3" >1.0000</td>
#       <td id="T_01690_row8_col4" class="data row8 col4" >1.0000</td>
#       <td id="T_01690_row8_col5" class="data row8 col5" >1.0000</td>
#       <td id="T_01690_row8_col6" class="data row8 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_01690_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_01690_row9_col0" class="data row9 col0" >1.0000</td>
#       <td id="T_01690_row9_col1" class="data row9 col1" >1.0000</td>
#       <td id="T_01690_row9_col2" class="data row9 col2" >1.0000</td>
#       <td id="T_01690_row9_col3" class="data row9 col3" >1.0000</td>
#       <td id="T_01690_row9_col4" class="data row9 col4" >1.0000</td>
#       <td id="T_01690_row9_col5" class="data row9 col5" >1.0000</td>
#       <td id="T_01690_row9_col6" class="data row9 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_01690_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_01690_row10_col0" class="data row10 col0" >1.0000</td>
#       <td id="T_01690_row10_col1" class="data row10 col1" >1.0000</td>
#       <td id="T_01690_row10_col2" class="data row10 col2" >1.0000</td>
#       <td id="T_01690_row10_col3" class="data row10 col3" >1.0000</td>
#       <td id="T_01690_row10_col4" class="data row10 col4" >1.0000</td>
#       <td id="T_01690_row10_col5" class="data row10 col5" >1.0000</td>
#       <td id="T_01690_row10_col6" class="data row10 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_01690_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_01690_row11_col0" class="data row11 col0" >0.0000</td>
#       <td id="T_01690_row11_col1" class="data row11 col1" >0.0000</td>
#       <td id="T_01690_row11_col2" class="data row11 col2" >0.0000</td>
#       <td id="T_01690_row11_col3" class="data row11 col3" >0.0000</td>
#       <td id="T_01690_row11_col4
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %% [markdown]
# By observing this plot, risk score clearly outweights every other metric, because they are directly correlated. The risk score is kinf of what we want to predict, but in form of anomaly in categories. For that reason, we will also drop the risk score, which will allow us to build a more realistic model.
#
# Another column that would cause the same issue is transaction_type, because it also has values like phishing and scam, that are directly correlated with a high anomaly risk. We will drop that one as well.

# %%
metaverse_data.drop(columns=['risk_score'], inplace=True)
metaverse_data.drop(columns=['transaction_type'], inplace=True)
metaverse_data.head()
# Out:
#    hour_of_day      amount  ip_prefix  login_frequency  session_duration  \
# 0           12  796.949206    192.000                3                48
# 1           19    0.010000    172.000                5                61
# 2           16  778.197390    192.168                3                74
# 3            9  300.838358    172.000                8               111
# 4           14  775.569344    172.160                6               100
#
#    purchase_pattern  age_group  anomaly
# 0                 0          0        1
# 1                 0          0        1
# 2                 0          0        1
# 3                 1          2        1
# 4                 1          2        2

# %%
input_data = metaverse_data.drop(columns=['anomaly'], axis=1)
output_data = metaverse_data['anomaly']

X_train, X_test, y_train, y_test = train_test_split(input_data, output_data, test_size=0.2, random_state=42)

X_train, y_train = SMOTE(random_state=42).fit_resample(X_train, y_train)

y_train.value_counts(), y_test.value_counts()

classification = setup(data = metaverse_data, train_size=0.8, target = 'anomaly', session_id=42, normalize=True, transformation=True)

best = compare_models()

results = pull()
# Out:
# <style type="text/css">
# #T_329eb_row8_col1, #T_329eb_row12_col1, #T_329eb_row14_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_329eb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_329eb_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_329eb_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_329eb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_329eb_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_329eb_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_329eb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_329eb_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_329eb_row1_col1" class="data row1 col1" >anomaly</td>
#     </tr>
#     <tr>
#       <th id="T_329eb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_329eb_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_329eb_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_329eb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_329eb_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_329eb_row3_col1" class="data row3 col1" >(78600, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_329eb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_329eb_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_329eb_row4_col1" class="data row4 col1" >(78600, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_329eb_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_329eb_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_329eb_row5_col1" class="data row5 col1" >(62880, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_329eb_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_329eb_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_329eb_row6_col1" class="data row6 col1" >(15720, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_329eb_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_329eb_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_329eb_row7_col1" class="data row7 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_329eb_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_329eb_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_329eb_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_329eb_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_329eb_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_329eb_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_329eb_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_329eb_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_329eb_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_329eb_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_329eb_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_329eb_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_329eb_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_329eb_row12_col0" class="data row12 col0" >Transformation</td>
#       <td id="T_329eb_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_329eb_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_329eb_row13_col0" class="data row13 col0" >Transformation method</td>
#       <td id="T_329eb_row13_col1" class="data row13 col1" >yeo-johnson</td>
#     </tr>
#     <tr>
#       <th id="T_329eb_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_329eb_row14_col0" class="data row14 col0" >Normalize</td>
#       <td id="T_329eb_row14_col1" class="data row14 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_329eb_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_329eb_row15_col0" class="data row15 col0" >Normalize method</td>
#       <td id="T_329eb_row15_col1" class="data row15 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_329eb_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_329eb_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_329eb_row16_col1" class="data row16 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_329eb_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_329eb_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_329eb_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_329eb_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_329eb_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_329eb_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_329eb_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_329eb_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_329eb_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_329eb_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_329eb_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_329eb_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_329eb_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_329eb_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_329eb_row21_col1" class="data row21 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_329eb_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_329eb_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_329eb_row22_col1" class="data row22 col1" >c500</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_06c3d th {
#   text-align: left;
# }
# #T_06c3d_row0_col0, #T_06c3d_row0_col2, #T_06c3d_row0_col4, #T_06c3d_row1_col0, #T_06c3d_row1_col1, #T_06c3d_row1_col3, #T_06c3d_row1_col4, #T_06c3d_row1_col5, #T_06c3d_row1_col6, #T_06c3d_row1_col7, #T_06c3d_row2_col0, #T_06c3d_row2_col1, #T_06c3d_row2_col2, #T_06c3d_row2_col3, #T_06c3d_row2_col4, #T_06c3d_row2_col5, #T_06c3d_row2_col6, #T_06c3d_row2_col7, #T_06c3d_row3_col0, #T_06c3d_row3_col1, #T_06c3d_row3_col2, #T_06c3d_row3_col3, #T_06c3d_row3_col4, #T_06c3d_row3_col5, #T_06c3d_row3_col6, #T_06c3d_row3_col7, #T_06c3d_row4_col0, #T_06c3d_row4_col1, #T_06c3d_row4_col2, #T_06c3d_row4_col3, #T_06c3d_row4_col4, #T_06c3d_row4_col5, #T_06c3d_row4_col6, #T_06c3d_row4_col7, #T_06c3d_row5_col0, #T_06c3d_row5_col1, #T_06c3d_row5_col2, #T_06c3d_row5_col3, #T_06c3d_row5_col4, #T_06c3d_row5_col5, #T_06c3d_row5_col6, #T_06c3d_row5_col7, #T_06c3d_row6_col0, #T_06c3d_row6_col1, #T_06c3d_row6_col2, #T_06c3d_row6_col3, #T_06c3d_row6_col4, #T_06c3d_row6_col5, #T_06c3d_row6_col6, #T_06c3d_row6_col7, #T_06c3d_row7_col0, #T_06c3d_row7_col1, #T_06c3d_row7_col2, #T_06c3d_row7_col3, #T_06c3d_row7_col4, #T_06c3d_row7_col5, #T_06c3d_row7_col6, #T_06c3d_row7_col7, #T_06c3d_row8_col0, #T_06c3d_row8_col1, #T_06c3d_row8_col2, #T_06c3d_row8_col3, #T_06c3d_row8_col4, #T_06c3d_row8_col5, #T_06c3d_row8_col6, #T_06c3d_row8_col7, #T_06c3d_row9_col0, #T_06c3d_row9_col1, #T_06c3d_row9_col2, #T_06c3d_row9_col3, #T_06c3d_row9_col4, #T_06c3d_row9_col5, #T_06c3d_row9_col6, #T_06c3d_row9_col7, #T_06c3d_row10_col0, #T_06c3d_row10_col1, #T_06c3d_row10_col2, #T_06c3d_row10_col3, #T_06c3d_row10_col4, #T_06c3d_row10_col5, #T_06c3d_row10_col6, #T_06c3d_row10_col7, #T_06c3d_row11_col0, #T_06c3d_row11_col1, #T_06c3d_row11_col2, #T_06c3d_row11_col3, #T_06c3d_row11_col4, #T_06c3d_row11_col5, #T_06c3d_row11_col6, #T_06c3d_row11_col7, #T_06c3d_row12_col0, #T_06c3d_row12_col1, #T_06c3d_row12_col2, #T_06c3d_row12_col3, #T_06c3d_row12_col5, #T_06c3d_row12_col6, #T_06c3d_row12_col7, #T_06c3d_row13_col0, #T_06c3d_row13_col1, #T_06c3d_row13_col2, #T_06c3d_row13_col3, #T_06c3d_row13_col4, #T_06c3d_row13_col5, #T_06c3d_row13_col6, #T_06c3d_row13_col7 {
#   text-align: left;
# }
# #T_06c3d_row0_col1, #T_06c3d_row0_col3, #T_06c3d_row0_col5, #T_06c3d_row0_col6, #T_06c3d_row0_col7, #T_06c3d_row1_col2, #T_06c3d_row12_col4 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_06c3d_row0_col8, #T_06c3d_row1_col8, #T_06c3d_row2_col8, #T_06c3d_row3_col8, #T_06c3d_row4_col8, #T_06c3d_row5_col8, #T_06c3d_row6_col8, #T_06c3d_row7_col8, #T_06c3d_row8_col8, #T_06c3d_row9_col8, #T_06c3d_row10_col8, #T_06c3d_row11_col8, #T_06c3d_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_06c3d_row12_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_06c3d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_06c3d_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_06c3d_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_06c3d_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_06c3d_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_06c3d_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_06c3d_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_06c3d_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_06c3d_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_06c3d_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_06c3d_level0_row0" class="row_heading level0 row0" >gbc</th>
#       <td id="T_06c3d_row0_col0" class="data row0 col0" >Gradient Boosting Classifier</td>
#       <td id="T_06c3d_row0_col1" class="data row0 col1" >0.8676</td>
#       <td id="T_06c3d_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_06c3d_row0_col3" class="data row0 col3" >0.8676</td>
#       <td id="T_06c3d_row0_col4" class="data row0 col4" >0.8012</td>
#       <td id="T_06c3d_row0_col5" class="data row0 col5" >0.8318</td>
#       <td id="T_06c3d_row0_col6" class="data row0 col6" >0.5528</td>
#       <td id="T_06c3d_row0_col7" class="data row0 col7" >0.5673</td>
#       <td id="T_06c3d_row0_col8" class="data row0 col8" >3.3760</td>
#     </tr>
#     <tr>
#       <th id="T_06c3d_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_06c3d_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_06c3d_row1_col1" class="data row1 col1" >0.8659</td>
#       <td id="T_06c3d_row1_col2" class="data row1 col2" >0.9019</td>
#       <td id="T_06c3d_row1_col3" class="data row1 col3" >0.8659</td>
#       <td id="T_06c3d_row1_col4" class="data row1 col4" >0.8269</td>
#       <td id="T_06c3d_row1_col5" class="data row1 col5" >0.8307</td>
#       <td id="T_06c3d_row1_col6" class="data row1 col6" >0.5470</td>
#       <td id="T_06c3d_row1_col7" class="data row1 col7" >0.5613</td>
#       <td id="T_06c3d_row1_col8" class="data row1 col8" >1.0170</td>
#     </tr>
#     <tr>
#       <th id="T_06c3d_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_06c3d_row2_col0" class="data row2 col0" >Random Forest Classifier</td>
#       <td id="T_06c3d_row2_col1" class="data row2 col1" >0.8455</td>
#       <td id="T_06c3d_row2_col2" class="data row2 col2" >0.8979</td>
#       <td id="T_06c3d_row2_col3" class="data row2 col3" >0.8455</td>
#       <td id="T_06c3d_row2_col4" class="data row2 col4" >0.8202</td>
#       <td id="T_06c3d_row2_col5" class="data row2 col5" >0.8288</td>
#       <td id="T_06c3d_row2_col6" class="data row2 col6" >0.5011</td>
#       <td id="T_06c3d_row2_col7" class="data row2 col7" >0.5054</td>
#       <td id="T_06c3d_row2_col8" class="data row2 col8" >0.6920</td>
#     </tr>
#     <tr>
#       <th id="T_06c3d_level0_row3" class="row_heading level0 row3" >lda</th>
#       <td id="T_06c3d_row3_col0" class="data row3 col0" >Linear Discriminant Analysis</td>
#       <td id="T_06c3d_row3_col1" class="data row3 col1" >0.8385</td>
#       <td id="T_06c3d_row3_col2" class="data row3 col2" >0.0000</td>
#       <td id="T_06c3d_row3_col3" class="data row3 col3" >0.8385</td>
#       <td id="T_06c3d_row3_col4" class="data row3 col4" >0.7650</td>
#       <td id="T_06c3d_row3_col5" class="data row3 col5" >0.7991</td>
#       <td id="T_06c3d_row3_col6" class="data row3 col6" >0.3767</td>
#       <td id="T_06c3d_row3_col7" class="data row3 col7" >0.4091</td>
#       <td id="T_06c3d_row3_col8" class="data row3 col8" >0.0680</td>
#     </tr>
#     <tr>
#       <th id="T_06c3d_level0_row4" class="row_heading level0 row4" >lr</th>
#       <td id="T_06c3d_row4_col0" class="data row4 col0" >Logistic Regression</td>
#       <td id="T_06c3d_row4_col1" class="data row4 col1" >0.8367</td>
#       <td id="T_06c3d_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_06c3d_row4_col3" class="data row4 col3" >0.8367</td>
#       <td id="T_06c3d_row4_col4" class="data row4 col4" >0.7618</td>
#       <td id="T_06c3d_row4_col5" class="data row4 col5" >0.7952</td>
#       <td id="T_06c3d_row4_col6" class="data row4 col6" >0.3487</td>
#       <td id="T_06c3d_row4_col7" class="data row4 col7" >0.3893</td>
#       <td id="T_06c3d_row4_col8" class="data row4 col8" >0.0980</td>
#     </tr>
#     <tr>
#       <th id="T_06c3d_level0_row5" class="row_heading level0 row5" >knn</th>
#       <td id="T_06c3d_row5_col0" class="data row5 col0" >K Neighbors Classifier</td>
#       <td id="T_06c3d_row5_col1" class="data row5 col1" >0.8365</td>
#       <td id="T_06c3d_row5_col2" class="data row5 col2" >0.8527</td>
#       <td id="T_06c3d_row5_col3" class="data row5 col3" >0.8365</td>
#       <td id="T_06c3d_row5_col4" class="data row5 col4" >0.8105</td>
#       <td id="T_06c3d_row5_col5" class="data row5 col5" >0.8207</td>
#       <td id="T_06c3d_row5_col6" class="data row5 col6" >0.4630</td>
#       <td id="T_06c3d_row5_col7" class="data row5 col7" >0.4673</t
# Processing:   0%|          | 0/61 [00:00<?, ?it/s]

# %% [markdown]
# ### Select the best model
# Based on the earlier analysis, the "gbc" emerges as the top-performing model due to its superiority in F1 score and also in accuracy.

# %%
model = GradientBoostingClassifier(random_state=42)
model.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='log_loss', max_depth=3,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_samples_leaf=1,
#                            min_samples_split=2, min_weight_fraction_leaf=0.0,
#                            n_estimators=100, n_iter_no_change=None,
#                            random_state=42, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)

# %%
model.score(X_train, y_train)
# Out:
# 0.8728823599099633

# %%
model = GradientBoostingClassifier(random_state=42)
model.fit(X_test, y_test)
# Out:
# GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='log_loss', max_depth=3,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_samples_leaf=1,
#                            min_samples_split=2, min_weight_fraction_leaf=0.0,
#                            n_estimators=100, n_iter_no_change=None,
#                            random_state=42, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)

# %%
model.score(X_test, y_test)
# Out:
# 0.8731552162849873

# %%
y_predicted = model.predict(X_test)
confusion_matrix_res = confusion_matrix(y_test, y_predicted)

ConfusionMatrixDisplay(confusion_matrix = confusion_matrix_res, display_labels = ["low_risk", "moderate_risk","high_risk"]).plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[69], line 4
#       1 y_predicted = model.predict(X_test)
#       2 confusion_matrix_res = confusion_matrix(y_test, y_predicted)
# ----> 4 ConfusionMatrixDisplay(confusion_matrix = confusion_matrix_res, display_labels = ["Benign", "Malignant",]).plot()
#       5 plt.show()
#
# File /opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_plot/confusion_matrix.py:181, in ConfusionMatrixDisplay.plot(self, include_values, cmap, xticks_rotation, values_format, ax, colorbar, im_kw, text_kw)
#     179 if colorbar:
#     180     fig.colorbar(self.im_, ax=ax)
# --> 181 ax.set(
#     182     xticks=np.arange(n_classes),
#     183     yticks=np.arange(n_classes),
#     184     xticklabels=display_labels,
#     185     yticklabels=display_labels,
#     186     ylabel="True label",
#     187     xlabel="Predicted label",
#     188 )
#     190 ax.set_ylim((n_classes - 0.5, -0.5))
#     191 plt.setp(ax.get_xticklabels(), rotation=xticks_rotation)
#
# File /opt/anaconda3/lib/python3.11/site-packages/matplotlib/artist.py:147, in Artist.__init_subclass__.<locals>.<lambda>(self, **kwargs)
#     139 if not hasattr(cls.set, '_autogenerated_signature'):
#     140     # Don't overwrite cls.set if the subclass or one of its parents
#     141     # has defined a set method set itself.
#     142     # If there was no explicit definition, cls.set is inherited from
#     143     # the hierarchy of auto-generated set methods, which hold the
#     144     # flag _autogenerated_signature.
#     145     return
# --> 147 cls.set = lambda self, **kwargs: Artist.set(self, **kwargs)
#     148 cls.set.__name__ = "set"
#     149 cls.set.__qualname__ = f"{cls.__qualname__}.set"
#
# File /opt/anaconda3/lib/python3.11/site-packages/matplotlib/artist.py:1231, in Artist.set(self, **kwargs)
#    1227 def set(self, **kwargs):
#    1228     # docstring and signature are auto-generated via
#    1229     # Artist._update_set_signature_and_docstring() at the end of the
#    1230     # module.
# -> 1231     return self._internal_update(cbook.normalize_kwargs(kwargs, self))
#
# File /opt/anaconda3/lib/python3.11/site-packages/matplotlib/artist.py:1223, in Artist._internal_update(self, kwargs)
#    1216 def _internal_update(self, kwargs):
#    1217     """
#    1218     Update artist properties without prenormalizing them, but generating
#    1219     errors as if calling `set`.
#    1220
#    1221     The lack of prenormalization is to maintain backcompatibility.
#    1222     """
# -> 1223     return self._update_props(
#    1224         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1225         "{prop_name!r}")
#
# File /opt/anaconda3/lib/python3.11/site-packages/matplotlib/artist.py:1199, in Artist._update_props(self, props, errfmt)
#    1196             if not callable(func):
#    1197                 raise AttributeError(
#    1198                     errfmt.format(cls=type(self), prop_name=k))
# -> 1199             ret.append(func(v))
#    1200 if ret:
#    1201     self.pchanged()
#
# File /opt/anaconda3/lib/python3.11/site-packages/matplotlib/axes/_base.py:74, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      73 def wrapper(self, *args, **kwargs):
# ---> 74     return get_method(self)(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/matplotlib/_api/deprecation.py:297, in rename_parameter.<locals>.wrapper(*args, **kwargs)
#     292     warn_deprecated(
#     293         since, message=f"The {old!r} parameter of {func.__name__}() "
#     294         f"has been renamed {new!r} since Matplotlib {since}; support "
#     295         f"for the old name will be dropped %(removal)s.")
#     296     kwargs[new] = kwargs.pop(old)
# --> 297 return func(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/matplotlib/axis.py:2018, in Axis.set_ticklabels(self, labels, minor, fontdict, **kwargs)
#    2014 if isinstance(locator, mticker.FixedLocator):
#    2015     # Passing [] as a list of labels is often used as a way to
#    2016     # remove all tick labels, so only error for > 0 labels
#    2017     if len(locator.locs) != len(labels) and len(labels) != 0:
# -> 2018         raise ValueError(
#    2019             "The number of FixedLocator locations"
#    2020             f" ({len(locator.locs)}), usually from a call to"
#    2021             " set_ticks, does not match"
#    2022             f" the number of labels ({len(labels)}).")
#    2023     tickd = {loc: lab for loc, lab in zip(locator.locs, labels)}
#    2024     func = functools.partial(self._format_with_dict, tickd)
#
# ValueError: The number of FixedLocator locations (3), usually from a call to set_ticks, does not match the number of labels (2).
